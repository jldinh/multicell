# %% [markdown]
# # Preparation

# %%
# %matplotlib notebook

# %% [markdown]
# # Imports

# %%
import multicell
import numpy as np

# %% [markdown]
# # Problem definition
#
# ## Simulation and tissue structure

# %%
sim = multicell.simulation_builder.generate_cell_grid_sim(20, 20, 1, 1e-3)
# Out:
# Topomesh importation: started
# - setting mesh
# - setting pos
# - updating properties
# Topomesh importation: finished (1.07 s)

# %% [markdown]
# ## Tissue growth

# %%
sim.enable_growth(n_steps=11)
sim.register_growth_method(multicell.growth.linear_growth, {"coefficient": [1.1, 1.05, 1.]})

# %% [markdown]
# ## Cell divisions

# %%
sim.enable_division(contraction=0)
sim.register_division_method(multicell.division.symmetrical_division)
sim.register_division_trigger(multicell.division.volume_trigger, {"volume_threshold": 2.})

# %% [markdown]
# ## Rendering

# %%
sim.register_renderer(multicell.rendering.MatplotlibRenderer, None, {"view_size": 60})

# %% [markdown]
# # Visualization of the initial state

# %%
sim.renderer.display()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Simulation

# %%
sim.simulate()
# Out:
# Growth step #0
# Growth of the tissue: 0.00158405303955 seconds
# Cell divisions: 1.09556698799 seconds
# <img src="data:image/png;base64,...">
# Growth step #1
# Growth of the tissue: 0.00082802772522 seconds
# Cell divisions: 1.06195998192 seconds
# <img src="data:image/png;base64,...">
# Growth step #2
# Growth of the tissue: 0.000978946685791 seconds
# Cell divisions: 1.03243803978 seconds
# <img src="data:image/png;base64,...">
# Growth step #3
# Growth of the tissue: 0.000833034515381 seconds
# Cell divisions: 1.02986311913 seconds
# <img src="data:image/png;base64,...">
# Growth step #4
# Growth of the tissue: 0.000868082046509 seconds
# Cell divisions: 3.75960302353 seconds
# <img src="data:image/png;base64,...">
# Growth step #5
# Growth of the tissue: 0.0224120616913 seconds
# Cell divisions: 3.16863393784 seconds
# <img src="data:image/png;base64,...">
# Growth step #6
# Growth of the tissue: 0.00297594070435 seconds
# Cell divisions: 3.20233201981 seconds
# <img src="data:image/png;base64,...">
# Growth step #7
# Growth of the tissue: 0.00794005393982 seconds
# Cell divisions: 3.10528898239 seconds
# <img src="data:image/png;base64,...">
# Growth step #8
# Growth of the tissue: 0.00284314155579 seconds
# Cell divisions: 3.08522200584 seconds
# <img src="data:image/png;base64,...">
# Growth step #9
# Growth of the tissue: 0.00311517715454 seconds
# Cell divisions: 9.6201839447 seconds
# <img src="data:image/png;base64,...">
# Growth step #10
# Growth of the tissue: 0.0130548477173 seconds
# Cell divisions: 8.48342394829 seconds
# <img src="data:image/png;base64,...">
