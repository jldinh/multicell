# %% [markdown]
# # Preparation

# %%
# %matplotlib notebook

# %% [markdown]
# # Imports

# %%
import multicell
import numpy as np

# %% [markdown]
# # Problem definition
#
# ## Simulation and tissue structure

# %%
sim = multicell.simulation_builder.generate_cell_grid_sim(20, 20, 1, 1e-3)
# Out:
# Topomesh importation: started
# - setting mesh
# - setting pos
# - updating properties
# Topomesh importation: finished (0.93 s)

# %% [markdown]
# ## Tissue growth

# %%
sim.enable_growth(n_steps=11)
sim.register_growth_method(multicell.growth.linear_growth, {"coefficient": [1.1, 1.05, 1.]})

# %% [markdown]
# ## Cell divisions

# %%
sim.enable_division(contraction=0)
sim.register_division_method(multicell.division.symmetrical_division)
sim.register_division_trigger(multicell.division.volume_trigger, {"volume_threshold": 2.})

# %% [markdown]
# ## Rendering

# %%
sim.register_renderer(multicell.rendering.MatplotlibRenderer, None, {"view_size": 60, "view": (90, -90)})

# %% [markdown]
# # Visualization of the initial state

# %%
sim.renderer.display()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Simulation

# %%
sim.simulate()
# Out:
# Growth step #0
# Growth of the tissue: 1.25268888474 seconds
# Cell divisions: 1.69577097893 seconds
# <img src="data:image/png;base64,...">
# Growth step #1
# Growth of the tissue: 0.903231859207 seconds
# Cell divisions: 1.15435910225 seconds
# <img src="data:image/png;base64,...">
# Growth step #2
# Growth of the tissue: 0.942300081253 seconds
# Cell divisions: 1.14796805382 seconds
# <img src="data:image/png;base64,...">
# Growth step #3
# Growth of the tissue: 0.990576028824 seconds
# Cell divisions: 1.07249593735 seconds
# <img src="data:image/png;base64,...">
# Growth step #4
# Growth of the tissue: 0.910889148712 seconds
# Cell divisions: 3.78049707413 seconds
# <img src="data:image/png;base64,...">
# Growth step #5
# Growth of the tissue: 2.3646531105 seconds
# Cell divisions: 3.04910111427 seconds
# <img src="data:image/png;base64,...">
# Growth step #6
# Growth of the tissue: 2.41876387596 seconds
# Cell divisions: 3.22093486786 seconds
# <img src="data:image/png;base64,...">
# Growth step #7
# Growth of the tissue: 2.4670188427 seconds
# Cell divisions: 3.00063705444 seconds
# <img src="data:image/png;base64,...">
# Growth step #8
# Growth of the tissue: 2.36130714417 seconds
# Cell divisions: 2.95292115211 seconds
# <img src="data:image/png;base64,...">
# Growth step #9
# Growth of the tissue: 2.323980093 seconds
# Cell divisions: 9.58647608757 seconds
# <img src="data:image/png;base64,...">
# Growth step #10
# Growth of the tissue: 5.12925601006 seconds
# Cell divisions: 8.53095388412 seconds
# <img src="data:image/png;base64,...">
