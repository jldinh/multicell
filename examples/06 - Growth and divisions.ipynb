# %% [markdown]
# # Preparation

# %%
# %matplotlib notebook

# %% [markdown]
# # Imports

# %%
import multicell
import numpy as np

# %% [markdown]
# # Problem definition
#
# ## Simulation and tissue structure

# %%
sim = multicell.simulation_builder.generate_cell_grid_sim(20, 20, 1, 1e-3)
# Out:
# Topomesh importation: started
# - setting mesh
# - setting pos
# - updating properties
# Topomesh importation: finished (1.67 s)

# %% [markdown]
# ## Tissue growth

# %%
sim.enable_growth(n_steps=11)
sim.register_growth_method(multicell.growth.linear_growth, {"coefficient": [1.1, 1.05, 1.]})

# %% [markdown]
# ## Cell divisions

# %%
sim.enable_division(contraction=0)
sim.register_division_method(multicell.division.symmetrical_division)
sim.register_division_trigger(multicell.division.volume_trigger, {"volume_threshold": 2.})

# %% [markdown]
# ## Rendering

# %%
sim.register_renderer(multicell.rendering.MatplotlibRenderer, None, {"view_size": 60, "view": (90, -90), "axes": False})

# %% [markdown]
# # Visualization of the initial state

# %%
sim.renderer.display()
# Out:
# <img src="data:image/png;base64,...">
# Time: 0.0

# %% [markdown]
# # Simulation

# %%
sim.simulate()
# Out:
# Growth step #0
# Growth of the tissue: 2.11687898636 seconds
# Cell divisions: 3.59297585487 seconds
# <img src="data:image/png;base64,...">
# Time: 0.0909090909091
# Growth step #1
# Growth of the tissue: 1.63008904457 seconds
# Cell divisions: 1.89819502831 seconds
# <img src="data:image/png;base64,...">
# Time: 0.181818181818
# Growth step #2
# Growth of the tissue: 1.60030198097 seconds
# Cell divisions: 1.89261984825 seconds
# <img src="data:image/png;base64,...">
# Time: 0.272727272727
# Growth step #3
# Growth of the tissue: 1.66297602654 seconds
# Cell divisions: 1.93280100822 seconds
# <img src="data:image/png;base64,...">
# Time: 0.363636363636
# Growth step #4
# Growth of the tissue: 1.76698303223 seconds
# Cell divisions: 7.91722512245 seconds
# <img src="data:image/png;base64,...">
# Time: 0.454545454545
# Growth step #5
# Growth of the tissue: 5.74899506569 seconds
# Cell divisions: 6.44037103653 seconds
# <img src="data:image/png;base64,...">
# Time: 0.545454545455
# Growth step #6
# Growth of the tissue: 4.37373209 seconds
# Cell divisions: 5.99302411079 seconds
# <img src="data:image/png;base64,...">
# Time: 0.636363636364
# Growth step #7
# Growth of the tissue: 3.83808016777 seconds
# Cell divisions: 3.86448812485 seconds
# <img src="data:image/png;base64,...">
# Time: 0.727272727273
# Growth step #8
# Growth of the tissue: 2.89462709427 seconds
# Cell divisions: 4.07571911812 seconds
# <img src="data:image/png;base64,...">
# Time: 0.818181818182
# Growth step #9
# Growth of the tissue: 2.90005898476 seconds
# Cell divisions: 12.7555060387 seconds
# <img src="data:image/png;base64,...">
# Time: 0.909090909091
# Growth step #10
# Growth of the tissue: 6.36587095261 seconds
# Cell divisions: 10.4480860233 seconds
# <img src="data:image/png;base64,...">
# Time: 1.0
