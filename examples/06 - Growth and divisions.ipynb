# %% [markdown]
# # Preparation

# %%
# %matplotlib notebook

# %% [markdown]
# # Imports

# %%
import multicell
import numpy as np

# %% [markdown]
# # Problem definition
#
# ## Simulation and tissue structure

# %%
sim = multicell.simulation_builder.generate_cell_grid_sim(20, 20, 1, 1e-3)
# Out:
# Topomesh importation: started
# - setting mesh
# - setting pos
# - updating properties
# Topomesh importation: finished (1.17 s)

# %% [markdown]
# ## Tissue growth

# %%
sim.enable_growth(n_steps=11)
sim.register_growth_method(multicell.growth.linear_growth, {"coefficient": [1.1, 1.05, 1.]})

# %% [markdown]
# ## Cell divisions

# %%
sim.enable_division(contraction=0)
sim.register_division_method(multicell.division.symmetrical_division)
sim.register_division_trigger(multicell.division.volume_trigger, {"volume_threshold": 2.})

# %% [markdown]
# ## Rendering

# %%
sim.register_renderer(multicell.rendering.MatplotlibRenderer, None, {"view_size": 60, "view": (90, -90), "axes": False})

# %% [markdown]
# # Visualization of the initial state

# %%
sim.renderer.display()
# Out:
# <img src="data:image/png;base64,...">
# Time: 0.0

# %% [markdown]
# # Simulation

# %%
sim.simulate()
# Out:
# Growth step #0
# Growth of the tissue: 1.18230891228 seconds
# Cell divisions: 1.37382984161 seconds
# <img src="data:image/png;base64,...">
# Time: 0.0909090909091
# Growth step #1
# Growth of the tissue: 1.17748403549 seconds
# Cell divisions: 1.36333990097 seconds
# <img src="data:image/png;base64,...">
# Time: 0.181818181818
# Growth step #2
# Growth of the tissue: 1.18793201447 seconds
# Cell divisions: 1.38411903381 seconds
# <img src="data:image/png;base64,...">
# Time: 0.272727272727
# Growth step #3
# Growth of the tissue: 1.17121696472 seconds
# Cell divisions: 1.37129306793 seconds
# <img src="data:image/png;base64,...">
# Time: 0.363636363636
# Growth step #4
# Growth of the tissue: 1.24676585197 seconds
# Cell divisions: 6.93644118309 seconds
# <img src="data:image/png;base64,...">
# Time: 0.454545454545
# Growth step #5
# Growth of the tissue: 2.97659397125 seconds
# Cell divisions: 3.9343020916 seconds
# <img src="data:image/png;base64,...">
# Time: 0.545454545455
# Growth step #6
# Growth of the tissue: 3.04558300972 seconds
# Cell divisions: 4.09412789345 seconds
# <img src="data:image/png;base64,...">
# Time: 0.636363636364
# Growth step #7
# Growth of the tissue: 2.9878950119 seconds
# Cell divisions: 3.95083403587 seconds
# <img src="data:image/png;base64,...">
# Time: 0.727272727273
# Growth step #8
# Growth of the tissue: 2.96240091324 seconds
# Cell divisions: 3.89602613449 seconds
# <img src="data:image/png;base64,...">
# Time: 0.818181818182
# Growth step #9
# Growth of the tissue: 2.91725707054 seconds
# Cell divisions: 12.0587329865 seconds
# <img src="data:image/png;base64,...">
# Time: 0.909090909091
# Growth step #10
# Growth of the tissue: 10.097933054 seconds
# Cell divisions: 16.6263711452 seconds
# <img src="data:image/png;base64,...">
# Time: 1.0
